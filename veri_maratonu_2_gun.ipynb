# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sbn
from collections import Counter

# %%
veri=pd.read_csv("olimpiyatlar_temizlenmis_20220204.csv")

# %%
ilk_veri=veri.iloc[0:110:]
ilk_veri_boy=ilk_veri.sort_values("boy",ascending=True)
yas=ilk_veri_boy.loc[:,["yas"]]
boy=ilk_veri_boy.loc[:,["boy"]]
yıl=ilk_veri_boy.loc[:,["yil"]]
kilo=ilk_veri_boy.loc[:,["kilo"]]
mp.plot(boy,yas,"g-",boy,kilo,"r--")

# %%
mp.scatter(boy,kilo)
mp.title("Boy Kilo Oranı")
mp.xlabel("boy")
mp.ylabel("kilo")
mp.grid(True)

# %%
isimler=["ahmet","efe","mehmet"]
boy3=[50,40,32]

mp.figure(figsize=(9,3))

mp.subplot(131)
mp.bar(isimler,boy3)

mp.subplot(132)
mp.scatter(isimler,boy3)

mp.subplot(133)
mp.step(isimler,boy3)

# %%
t=np.arange(0,20,0.1)
f=np.exp(-t)*np.cos(2*np.pi*t)
mp.plot(t,f,"k",t,f,"bo")
mp.axis([0,10,-1,1])
# Out:
# (0.0, 10.0, -1.0, 1.0)
